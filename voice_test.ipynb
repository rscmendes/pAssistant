# %% [markdown]
# This notebook is to test the vocoder and to find a nice voice for the assistant.

# %%
import torch
from transformers import SpeechT5Processor, SpeechT5ForTextToSpeech, SpeechT5HifiGan
from datasets import load_dataset
from audio_helper import play_audio

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
_tts_model = SpeechT5ForTextToSpeech.from_pretrained("microsoft/speecht5_tts")
_tts_model.to(device)

_tts_vocoder = SpeechT5HifiGan.from_pretrained("microsoft/speecht5_hifigan")
_tts_vocoder.to(device)

_tts_processor = SpeechT5Processor.from_pretrained("microsoft/speecht5_tts")

message = "Ricardo, how are you doing today?"

sampling_rate = 16000

# TODO replace with simpler approach
embeddings_dataset = load_dataset("Matthijs/cmu-arctic-xvectors", split="validation")

# %%
len(embeddings_dataset)
# Out:
# 7931

# %%
_speaker_embeddings = torch.tensor(embeddings_dataset[1]["xvector"]).unsqueeze(0).to(device)

inputs = _tts_processor(text=message, return_tensors="pt").to(device)
speech = _tts_model.generate_speech(inputs["input_ids"], _speaker_embeddings, vocoder=_tts_vocoder)
play_audio(speech.to('cpu'), sampling_rate)

# %% [markdown]
# I could make a cycle through all embeddings, but let's instead create a grid with play buttons

# %%
from IPython.display import display
import ipywidgets as widgets

PAGE_SIZE = 12  # Number of buttons to load at once
GRID_COLUMNS = 4  # Number of columns in the grid

# Example generator for audio data
def audio_data_generator():
    for i in range(len(embeddings_dataset)):  # Example range, adjust as needed
        _speaker_embeddings = torch.tensor(embeddings_dataset[i]["xvector"]).unsqueeze(0).to(device)
        inputs = _tts_processor(text=message, return_tensors="pt").to(device)
        speech = _tts_model.generate_speech(inputs["input_ids"], _speaker_embeddings, vocoder=_tts_vocoder)
        yield f'button_{i}', speech.to('cpu')

audio_gen = audio_data_generator()
audio_data_dict = {}

# Function to handle button click
def on_button_click(b):
    audio_data = audio_data_dict[b.description]
    play_audio(audio_data, sampling_rate)

# Function to load more buttons in a grid layout
def load_more_buttons(container, n=PAGE_SIZE):
    new_buttons = []
    for _ in range(n):
        try:
            label, audio_data = next(audio_gen)
            audio_data_dict[label] = audio_data
            button = widgets.Button(description=label)
            button.on_click(on_button_click)
            new_buttons.append(button)
        except StopIteration:
            break
    
    # Arrange buttons in a grid
    rows = []
    for i in range(0, len(new_buttons), GRID_COLUMNS):
        row = new_buttons[i:i+GRID_COLUMNS]
        rows.append(widgets.HBox(row))
    
    container.children = tuple(list(container.children) + rows)

# Create the initial set of buttons
button_container = widgets.VBox()
load_more_buttons(button_container)

# Create a scrollable container
scrollable_box = widgets.Box([button_container], layout=widgets.Layout(
    overflow_y='auto',
    border='1px solid black',
    width='500px',  # Adjust width as needed
    height='300px',
    display='block'
))

# Load more button
load_more_button = widgets.Button(description="Load More")
def load_more_on_click(b):
    load_more_buttons(button_container)

load_more_button.on_click(load_more_on_click)

# Display the UI
display(scrollable_box)
display(load_more_button)
# Out:
# Box(children=(VBox(children=(HBox(children=(Button(description='button_0', style=ButtonStyle()), Button(descri…
# Button(description='Load More', style=ButtonStyle())

# %% [markdown]
# I thought this would be easier, let's find it in the dataset. From the description:
#     bdl (US male)
#     slt (US female)
#     jmk (Canadian male)
#     awb (Scottish male)
#     rms (US male)
#     clb (US female)
#     ksp (Indian male)
#
# Let's find the Scottish male.

# %%
embeddings_dataset['filename'][1500:2000]
# Out:
# ['cmu_us_bdl_arctic-wav-arctic_a0363',
#  'cmu_us_bdl_arctic-wav-arctic_a0364',
#  'cmu_us_bdl_arctic-wav-arctic_a0365',
#  'cmu_us_bdl_arctic-wav-arctic_a0366',
#  'cmu_us_bdl_arctic-wav-arctic_a0367',
#  'cmu_us_bdl_arctic-wav-arctic_a0368',
#  'cmu_us_bdl_arctic-wav-arctic_a0369',
#  'cmu_us_bdl_arctic-wav-arctic_a0370',
#  'cmu_us_bdl_arctic-wav-arctic_a0371',
#  'cmu_us_bdl_arctic-wav-arctic_a0372',
#  'cmu_us_bdl_arctic-wav-arctic_a0373',
#  'cmu_us_bdl_arctic-wav-arctic_a0374',
#  'cmu_us_bdl_arctic-wav-arctic_a0375',
#  'cmu_us_bdl_arctic-wav-arctic_a0376',
#  'cmu_us_bdl_arctic-wav-arctic_a0377',
#  'cmu_us_bdl_arctic-wav-arctic_a0378',
#  'cmu_us_bdl_arctic-wav-arctic_a0379',
#  'cmu_us_bdl_arctic-wav-arctic_a0380',
#  'cmu_us_bdl_arctic-wav-arctic_a0381',
#  'cmu_us_bdl_arctic-wav-arctic_a0382',
#  'cmu_us_bdl_arctic-wav-arctic_a0383',
#  'cmu_us_bdl_arctic-wav-arctic_a0384',
#  'cmu_us_bdl_arctic-wav-arctic_a0385',
#  'cmu_us_bdl_arctic-wav-arctic_a0386',
#  'cmu_us_bdl_arctic-wav-arctic_a0387',
#  'cmu_us_bdl_arctic-wav-arctic_a0388',
#  'cmu_us_bdl_arctic-wav-arctic_a0389',
#  'cmu_us_bdl_arctic-wav-arctic_a0390',
#  'cmu_us_bdl_arctic-wav-arctic_a0391',
#  'cmu_us_bdl_arctic-wav-arctic_a0392',
#  'cmu_us_bdl_arctic-wav-arctic_a0393',
#  'cmu_us_bdl_arctic-wav-arctic_a0394',
#  'cmu_us_bdl_arctic-wav-arctic_a0395',
#  'cmu_us_bdl_arctic-wav-arctic_a0396',
#  'cmu_us_bdl_arctic-wav-arctic_a0397',
#  'cmu_us_bdl_arctic-wav-arctic_a0398',
#  'cmu_us_bdl_arctic-wav-arctic_a0399',
#  'cmu_us_bdl_arctic-wav-arctic_a0400',
#  'cmu_us_bdl_arctic-wav-arctic_a0401',
#  'cmu_us_bdl_arctic-wav-arctic_a0402',
#  'cmu_us_bdl_arctic-wav-arctic_a0403',
#  'cmu_us_bdl_arctic-wav-arctic_a0404',
#  'cmu_us_bdl_arctic-wav-arctic_a0405',
#  'cmu_us_bdl_arctic-wav-arctic_a0406',
#  'cmu_us_bdl_arctic-wav-arctic_a0407',
#  'cmu_us_bdl_arctic-wav-arctic_a0408',
#  'cmu_us_bdl_arctic-wav-arctic_a0409',
#  'cmu_us_bdl_arctic-wav-arctic_a0410',
#  'cmu_us_bdl_arctic-wav-arctic_a0411',
#  'cmu_us_bdl_arctic-wav-arctic_a0412',
#  'cmu_us_bdl_arctic-wav-arctic_a0413',
#  'cmu_us_bdl_arctic-wav-arctic_a0414',
#  'cmu_us_bdl_arctic-wav-arctic_a0415',
#  'cmu_us_bdl_arctic-wav-arctic_a0416',
#  'cmu_us_bdl_arctic-wav-arctic_a0417',
#  'cmu_us_bdl_arctic-wav-arctic_a0418',
#  'cmu_us_bdl_arctic-wav-arctic_a0419',
#  'cmu_us_bdl_arctic-wav-arctic_a0420',
#  'cmu_us_bdl_arctic-wav-arctic_a0421',
#  'cmu_us_bdl_arctic-wav-arctic_a0422',
#  'cmu_us_bdl_arctic-wav-arctic_a0423',
#  'cmu_us_bdl_arctic-wav-arctic_a0424',
#  'cmu_us_bdl_arctic-wav-arctic_a0425',
#  'cmu_us_bdl_arctic-wav-arctic_a0426',
#  'cmu_us_bdl_arctic-wav-arctic_a0427',
#  'cmu_us_bdl_arctic-wav-arctic_a0428',
#  'cmu_us_bdl_arctic-wav-arctic_a0429',
#  'cmu_us_bdl_arctic-wav-arctic_a0430',
#  'cmu_us_bdl_arctic-wav-arctic_a0431',
#  'cmu_us_bdl_arctic-wav-arctic_a0432',
#  'cmu_us_bdl_arctic-wav-arctic_a0433',
#  'cmu_us_bdl_arctic-wav-arctic_a0434',
#  'cmu_us_bdl_arctic-wav-arctic_a0435',
#  'cmu_us_bdl_arctic-wav-arctic_a0436',
#  'cmu_us_bdl_arctic-wav-arctic_a0437',
#  'cmu_us_bdl_arctic-wav-arctic_a0438',
#  'cmu_us_bdl_arctic-wav-arctic_a0439',
#  'cmu_us_bdl_arctic-wav-arctic_a0440',
#  'cmu_us_bdl_arctic-wav-arctic_a0441',
#  'cmu_us_bdl_arctic-wav-arctic_a0442',
#  'cmu_us_bdl_arctic-wav-arctic_a0443',
#  'cmu_us_bdl_arctic-wav-arctic_a0444',
#  'cmu_us_bdl_arctic-wav-arctic_a0445',
#  'cmu_us_bdl_arctic-wav-arctic_a0446',
#  'cmu_us_bdl_arctic-wav-arctic_a0447',
#  'cmu_us_bdl_arctic-wav-arctic_a0448',
#  'cmu_us_bdl_arctic-wav-arctic_a0449',
#  'cmu_us_bdl_arctic-wav-arctic_a0450',
#  'cmu_us_bdl_arctic-wav-arctic_a0451',
#  'cmu_us_bdl_arctic-wav-arctic_a0452',
#  'cmu_us_bdl_arctic-wav-arctic_a0453',
#  'cmu_us_bdl_arctic-wav-arctic_a0454',
#  'cmu_us_bdl_arctic-wav-arctic_a0455',
#  'cmu_us_bdl_arctic-wav-arctic_a0456',
#  'cmu_us_bdl_arctic-wav-arctic_a0457',
#  'cmu_us_bdl_arctic-wav-arctic_a0458',
#  'cmu_us_bdl_arctic-wav-arctic_a0459',
#  'cmu_us_bdl_arctic-wav-arctic_a0460',
#  'cmu_us_bdl_arctic-wav-arctic_a0461',
#  'cmu_us_bdl_arctic-wav-arctic_a0462',
#  'cmu_us_bdl_arctic-wav-arctic_a0463',
#  'cmu_us_bdl_arctic-wav-arctic_a0464',
#  'cmu_us_bdl_arctic-wav-arctic_a0465',
#  'cmu_us_bdl_arctic-wav-arctic_a0466',
#  'cmu_us_bdl_arctic-wav-arctic_a0467',
#  'cmu_us_bdl_arctic-wav-arctic_a0468',
#  'cmu_us_bdl_arctic-wav-arctic_a0469',
#  'cmu_us_bdl_arctic-wav-arctic_a0470',
#  'cmu_us_bdl_arctic-wav-arctic_a0471',
#  'cmu_us_bdl_arctic-wav-arctic_a0472',
#  'cmu_us_bdl_arctic-wav-arctic_a0473',
#  'cmu_us_bdl_arctic-wav-arctic_a0474',
#  'cmu_us_bdl_arctic-wav-arctic_a0475',
#  'cmu_us_bdl_arctic-wav-arctic_a0476',
#  'cmu_us_bdl_arctic-wav-arctic_a0477',
#  'cmu_us_bdl_arctic-wav-arctic_a0478',
#  'cmu_us_bdl_arctic-wav-arctic_a0479',
#  'cmu_us_bdl_arctic-wav-arctic_a0480',
#  'cmu_us_bdl_arctic-wav-arctic_a0481',
#  'cmu_us_bdl_arctic-wav-arctic_a0482',
#  'cmu_us_bdl_arctic-wav-arctic_a0483',
#  'cmu_us_bdl_arctic-wav-arctic_a0484',
#  'cmu_us_bdl_arctic-wav-arctic_a0485',
#  'cmu_us_bdl_arctic-wav-arctic_a0486',
#  'cmu_us_bdl_arctic-wav-arctic_a0487',
#  'cmu_us_bdl_arctic-wav-arctic_a0488',
#  'cmu_us_bdl_arctic-wav-arctic_a0489',
#  'cmu_us_bdl_arctic-wav-arctic_a0490',
#  'cmu_us_bdl_arctic-wav-arctic_a0491',
#  'cmu_us_bdl_arctic-wav-arctic_a0492',
#  'cmu_us_bdl_arctic-wav-arctic_a0493',
#  'cmu_us_bdl_arctic-wav-arctic_a0494',
#  'cmu_us_bdl_arctic-wav-arctic_a0495',
#  'cmu_us_bdl_arctic-wav-arctic_a0496',
#  'cmu_us_bdl_arctic-wav-arctic_a0497',
#  'cmu_us_bdl_arctic-wav-arctic_a0498',
#  'cmu_us_bdl_arctic-wav-arctic_a0499',
#  'cmu_us_bdl_arctic-wav-arctic_a0500',
#  'cmu_us_bdl_arctic-wav-arctic_a0501',
#  'cmu_us_bdl_arctic-wav-arctic_a0502',
#  'cmu_us_bdl_arctic-wav-arctic_a0503',
#  'cmu_us_bdl_arctic-wav-arctic_a0504',
#  'cmu_us_bdl_arctic-wav-arctic_a0505',
#  'cmu_us_bdl_arctic-wav-arctic_a0506',
#  'cmu_us_bdl_arctic-wav-arctic_a0507',
#  'cmu_us_bdl_arctic-wav-arctic_a0508',
#  'cmu_us_bdl_arctic-wav-arctic_a0509',
#  'cmu_us_bdl_arctic-wav-arctic_a0510',
#  'cmu_us_bdl_arctic-wav-arctic_a0511',
#  'cmu_us_bdl_arctic-wav-arctic_a0512',
#  'cmu_us_bdl_arctic-wav-arctic_a0513',
#  'cmu_us_bdl_arctic-wav-arctic_a0514',
#  'cmu_us_bdl_arctic-wav-arctic_a0515',
#  'cmu_us_bdl_arctic-wav-arctic_a0516',
#  'cmu_us_bdl_arctic-wav-arctic_a0517',
#  'cmu_us_bdl_arctic-wav-arctic_a0518',
#  'cmu_us_bdl_arctic-wav-arctic_a0519',
#  'cmu_us_bdl_arctic-wav-arctic_a0520',
#  'cmu_us_bdl_arctic-wav-arctic_a0521',
#  'cmu_us_bdl_arctic-wav-arctic_a0522',
#  'cmu_us_bdl_arctic-wav-arctic_a0523',
#  'cmu_us_bdl_arctic-wav-arctic_a0524',
#  'cmu_us_bdl_arctic-wav-arctic_a0525',
#  'cmu_us_bdl_arctic-wav-arctic_a0526',
#  'cmu_us_bdl_arctic-wav-arctic_a0527',
#  'cmu_us_bdl_arctic-wav-arctic_a0528',
#  'cmu_us_bdl_arctic-wav-arctic_a0529',
#  'cmu_us_bdl_arctic-wav-arctic_a0530',
#  'cmu_us_bdl_arctic-wav-arctic_a0531',
#  'cmu_us_bdl_arctic-wav-arctic_a0532',
#  'cmu_us_bdl_arctic-wav-arctic_a0533',
#  'cmu_us_bdl_arctic-wav-arctic_a0534',
#  'cmu_us_bdl_arctic-wav-arctic_a0535',
#  'cmu_us_bdl_arctic-wav-arctic_a0536',
#  'cmu_us_bdl_arctic-wav-arctic_a0537',
#  'cmu_us_bdl_arctic-wav-arctic_a0538',
#  'cmu_us_bdl_arctic-wav-arctic_a0539',
#  'cmu_us_bdl_arctic-wav-arctic_a0540',
#  'cmu_us_bdl_arctic-wav-arctic_a0541',
#  'cmu_us_bdl_arctic-wav-arctic_a0542',
#  'cmu_us_bdl_arctic-wav-arctic_a0543',
#  'cmu_us_bdl_arctic-wav-arctic_a0544',
#  'cmu_us_bdl_arctic-wav-arctic_a0545',
#  'cmu_us_bdl_arctic-wav-arctic_a0546',
#  'cmu_us_bdl_arctic-wav-arctic_a0547',
#  'cmu_us_bdl_arctic-wav-arctic_a0548',
#  'cmu_us_bdl_arctic-wav-arctic_a0549',
#  'cmu_us_bdl_arctic-wav-arctic_a0550',
#  'cmu_us_bdl_arctic-wav-arctic_a0551',
#  'cmu_us_bdl_arctic-wav-arctic_a0552',
#  'cmu_us_bdl_arctic-wav-arctic_a0553',
#  'cmu_us_bdl_arctic-wav-arctic_a0554',
#  'cmu_us_bdl_arctic-wav-arctic_a0555',
#  'cmu_us_bdl_arctic-wav-arctic_a0556',
#  'cmu_us_bdl_arctic-wav-arctic_a0557',
#  'cmu_us_bdl_arctic-wav-arctic_a0558',
#  'cmu_us_bdl_arctic-wav-arctic_a0559',
#  'cmu_us_bdl_arctic-wav-arctic_a0560',
#  'cmu_us_bdl_arctic-wav-arctic_a0561',
#  'cmu_us_bdl_arctic-wav-arctic_a0562',
#  'cmu_us_bdl_arctic-wav-arctic_a0563',
#  'cmu_us_bdl_arctic-wav-arctic_a0564',
#  'cmu_us_bdl_arctic-wav-arctic_a0565',
#  'cmu_us_bdl_arctic-wav-arctic_a0566',
#  'cmu_us_bdl_arctic-wav-arctic_a0567',
#  'cmu_us_bdl_arctic-wav-arctic_a0568',
#  'cmu_us_bdl_arctic-wav-arctic_a0569',
#  'cmu_us_bdl_arctic-wav-arctic_a0570',
#  'cmu_us_bdl_arctic-wav-arctic_a0571',
#  'cmu_us_bdl_arctic-wav-arctic_a0572',
#  'cmu_us_bdl_arctic-wav-arctic_a0573',
#  'cmu_us_bdl_arctic-wav-arctic_a0574',
#  'cmu_us_bdl_arctic-wav-arctic_a0575',
#  'cmu_us_bdl_arctic-wav-arctic_a0576',
#  'cmu_us_bdl_arctic-wav-arctic_a0577',
#  'cmu_us_bdl_arctic-wav-arctic_a0578',
#  'cmu_us_bdl_arctic-wav-arctic_a0579',
#  'cmu_us_bdl_arctic-wav-arctic_a0580',
#  'cmu_us_bdl_arctic-wav-arctic_a0581',
#  'cmu_us_bdl_arctic-wav-arctic_a0582',
#  'cmu_us_bdl_arctic-wav-arctic_a0583',
#  'cmu_us_bdl_arctic-wav-arctic_a0584',
#  'cmu_us_bdl_arctic-wav-arctic_a0585',
#  'cmu_us_bdl_arctic-wav-arctic_a0586',
#  'cmu_us_bdl_arctic-wav-arctic_a0587',
#  'cmu_us_bdl_arctic-wav-arctic_a0588',
#  'cmu_us_bdl_arctic-wav-arctic_a0589',
#  'cmu_us_bdl_arctic-wav-arctic_a0590',
#  'cmu_us_bdl_arctic-wav-arctic_a0591',
#  'cmu_us_bdl_arctic-wav-arctic_a0592',
#  'cmu_us_bdl_arctic-wav-arctic_a0593',
#  'cmu_us_bdl_arctic-wav-arctic_b0001',
#  'cmu_us_bdl_arctic-wav-arctic_b0002',
#  'cmu_us_bdl_arctic-wav-arctic_b0003',
#  'cmu_us_bdl_arctic-wav-arctic_b0004',
#  'cmu_us_bdl_arctic-wav-arctic_b0005',
#  'cmu_us_bdl_arctic-wav-arctic_b0006',
#  'cmu_us_bdl_arctic-wav-arctic_b0007',
#  'cmu_us_bdl_arctic-wav-arctic_b0008',
#  'cmu_us_bdl_arctic-wav-arctic_b0009',
#  'cmu_us_bdl_arctic-wav-arctic_b0010',
#  'cmu_us_bdl_arctic-wav-arctic_b0011',
#  'cmu_us_bdl_arctic-wav-arctic_b0012',
#  'cmu_us_bdl_arctic-wav-arctic_b0013',
#  'cmu_us_bdl_arctic-wav-arctic_b0014',
#  'cmu_us_bdl_arctic-wav-arctic_b0015',
#  'cmu_us_bdl_arctic-wav-arctic_b0016',
#  'cmu_us_bdl_arctic-wav-arctic_b0017',
#  'cmu_us_bdl_arctic-wav-arctic_b0018',
#  'cmu_us_bdl_arctic-wav-arctic_b0019',
#  'cmu_us_bdl_arctic-wav-arctic_b0020',
#  'cmu_us_bdl_arctic-wav-arctic_b0021',
#  'cmu_us_bdl_arctic-wav-arctic_b0022',
#  'cmu_us_bdl_arctic-wav-arctic_b0023',
#  'cmu_us_bdl_arctic-wav-arctic_b0024',
#  'cmu_us_bdl_arctic-wav-arctic_b0025',
#  'cmu_us_bdl_arctic-wav-arctic_b0026',
#  'cmu_us_bdl_arctic-wav-arctic_b0027',
#  'cmu_us_bdl_arctic-wav-arctic_b0028',
#  'cmu_us_bdl_arctic-wav-arctic_b0029',
#  'cmu_us_bdl_arctic-wav-arctic_b0030',
#  'cmu_us_bdl_arctic-wav-arctic_b0031',
#  'cmu_us_bdl_arctic-wav-arctic_b0032',
#  'cmu_us_bdl_arctic-wav-arctic_b0033',
#  'cmu_us_bdl_arctic-wav-arctic_b0034',
#  'cmu_us_bdl_arctic-wav-arctic_b0035',
#  'cmu_us_bdl_arctic-wav-arctic_b0036',
#  'cmu_us_bdl_arctic-wav-arctic_b0037',
#  'cmu_us_bdl_arctic-wav-arctic_b0038',
#  'cmu_us_bdl_arctic-wav-arctic_b0039',
#  'cmu_us_bdl_arctic-wav-arctic_b0040',
#  'cmu_us_bdl_arctic-wav-arctic_b0041',
#  'cmu_us_bdl_arctic-wav-arctic_b0042',
#  'cmu_us_bdl_arctic-wav-arctic_b0043',
#  'cmu_us_bdl_arctic-wav-arctic_b0044',
#  'cmu_us_bdl_arctic-wav-arctic_b0045',
#  'cmu_us_bdl_arctic-wav-arctic_b0046',
#  'cmu_us_bdl_arctic-wav-arctic_b0047',
#  'cmu_us_bdl_arctic-wav-arctic_b0048',
#  'cmu_us_bdl_arctic-wav-arctic_b0049',
#  'cmu_us_bdl_arctic-wav-arctic_b0050',
#  'cmu_us_bdl_arctic-wav-arctic_b0051',
#  'cmu_us_bdl_arctic-wav-arctic_b0052',
#  'cmu_us_bdl_arctic-wav-arctic_b0053',
#  'cmu_us_bdl_arctic-wav-arctic_b0054',
#  'cmu_us_bdl_arctic-wav-arctic_b0055',
#  'cmu_us_bdl_arctic-wav-arctic_b0056',
#  'cmu_us_bdl_arctic-wav-arctic_b0057',
#  'cmu_us_bdl_arctic-wav-arctic_b0058',
#  'cmu_us_bdl_arctic-wav-arctic_b0059',
#  'cmu_us_bdl_arctic-wav-arctic_b0060',
#  'cmu_us_bdl_arctic-wav-arctic_b0061',
#  'cmu_us_bdl_arctic-wav-arctic_b0062',
#  'cmu_us_bdl_arctic-wav-arctic_b0063',
#  'cmu_us_bdl_arctic-wav-arctic_b0064',
#  'cmu_us_bdl_arctic-wav-arctic_b0065',
#  'cmu_us_bdl_arctic-wav-arctic_b0066',
#  'cmu_us_bdl_arctic-wav-arctic_b0067',
#  'cmu_us_bdl_arctic-wav-arctic_b0068',
#  'cmu_us_bdl_arctic-wav-arctic_b0069',
#  'cmu_us_bdl_arctic-wav-arctic_b0070',
#  'cmu_us_bdl_arctic-wav-arctic_b0071',
#  'cmu_us_bdl_arctic-wav-arctic_b0072',
#  'cmu_us_bdl_arctic-wav-arctic_b0073',
#  'cmu_us_bdl_arctic-wav-arctic_b0074',
#  'cmu_us_bdl_arctic-wav-arctic_b0075',
#  'cmu_us_bdl_arctic-wav-arctic_b0076',
#  'cmu_us_bdl_arctic-wav-arctic_b0077',
#  'cmu_us_bdl_arctic-wav-arctic_b0078',
#  'cmu_us_bdl_arctic-wav-arctic_b0079',
#  'cmu_us_bdl_arctic-wav-arctic_b0080',
#  'cmu_us_bdl_arctic-wav-arctic_b0081',
#  'cmu_us_bdl_arctic-wav-arctic_b0082',
#  'cmu_us_bdl_arctic-wav-arctic_b0083',
#  'cmu_us_bdl_arctic-wav-arctic_b0084',
#  'cmu_us_bdl_arctic-wav-arctic_b0085',
#  'cmu_us_bdl_arctic-wav-arctic_b0086',
#  'cmu_us_bdl_arctic-wav-arctic_b0087',
#  'cmu_us_bdl_arctic-wav-arctic_b0088',
#  'cmu_us_bdl_arctic-wav-arctic_b0089',
#  'cmu_us_bdl_arctic-wav-arctic_b0090',
#  'cmu_us_bdl_arctic-wav-arctic_b0091',
#  'cmu_us_bdl_arctic-wav-arctic_b0092',
#  'cmu_us_bdl_arctic-wav-arctic_b0093',
#  'cmu_us_bdl_arctic-wav-arctic_b0094',
#  'cmu_us_bdl_arctic-wav-arctic_b0095',
#  'cmu_us_bdl_arctic-wav-arctic_b0096',
#  'cmu_us_bdl_arctic-wav-arctic_b0097',
#  'cmu_us_bdl_arctic-wav-arctic_b0098',
#  'cmu_us_bdl_arctic-wav-arctic_b0099',
#  'cmu_us_bdl_arctic-wav-arctic_b0100',
#  'cmu_us_bdl_arctic-wav-arctic_b0101',
#  'cmu_us_bdl_arctic-wav-arctic_b0102',
#  'cmu_us_bdl_arctic-wav-arctic_b0103',
#  'cmu_us_bdl_arctic-wav-arctic_b0104',
#  'cmu_us_bdl_arctic-wav-arctic_b0105',
#  'cmu_us_bdl_arctic-wav-arctic_b0106',
#  'cmu_us_bdl_arctic-wav-arctic_b0107',
#  'cmu_us_bdl_arctic-wav-arctic_b0108',
#  'cmu_us_bdl_arctic-wav-arctic_b0109',
#  'cmu_us_bdl_arctic-wav-arctic_b0110',
#  'cmu_us_bdl_arctic-wav-arctic_b0111',
#  'cmu_us_bdl_arctic-wav-arctic_b0112',
#  'cmu_us_bdl_arctic-wav-arctic_b0113',
#  'cmu_us_bdl_arctic-wav-arctic_b0114',
#  'cmu_us_bdl_arctic-wav-arctic_b0115',
#  'cmu_us_bdl_arctic-wav-arctic_b0116',
#  'cmu_us_bdl_arctic-wav-arctic_b0117',
#  'cmu_us_bdl_arctic-wav-arctic_b0118',
#  'cmu_us_bdl_arctic-wav-arctic_b0119',
#  'cmu_us_bdl_arctic-wav-arctic_b0120',
#  'cmu_us_bdl_arctic-wav-arctic_b0121',
#  'cmu_us_bdl_arctic-wav-arctic_b0122',
#  'cmu_us_bdl_arctic-wav-arctic_b0123',
#  'cmu_us_bdl_arctic-wav-arctic_b0124',
#  'cmu_us_bdl_arctic-wav-arctic_b0125',
#  'cmu_us_bdl_arctic-wav-arctic_b0126',
#  'cmu_us_bdl_arctic-wav-arctic_b0127',
#  'cmu_us_bdl_arctic-wav-arctic_b0128',
#  'cmu_us_bdl_arctic-wav-arctic_b0129',
#  'cmu_us_bdl_arctic-wav-arctic_b0130',
#  'cmu_us_bdl_arctic-wav-arctic_b0131',
#  'cmu_us_bdl_arctic-wav-arctic_b0132',
#  'cmu_us_bdl_arctic-wav-arctic_b0133',
#  'cmu_us_bdl_arctic-wav-arctic_b0134',
#  'cmu_us_bdl_arctic-wav-arctic_b0135',
#  'cmu_us_bdl_arctic-wav-arctic_b0136',
#  'cmu_us_bdl_arctic-wav-arctic_b0137',
#  'cmu_us_bdl_arctic-wav-arctic_b0138',
#  'cmu_us_bdl_arctic-wav-arctic_b0139',
#  'cmu_us_bdl_arctic-wav-arctic_b0140',
#  'cmu_us_bdl_arctic-wav-arctic_b0141',
#  'cmu_us_bdl_arctic-wav-arctic_b0142',
#  'cmu_us_bdl_arctic-wav-arctic_b0143',
#  'cmu_us_bdl_arctic-wav-arctic_b0144',
#  'cmu_us_bdl_arctic-wav-arctic_b0145',
#  'cmu_us_bdl_arctic-wav-arctic_b0146',
#  'cmu_us_bdl_arctic-wav-arctic_b0147',
#  'cmu_us_bdl_arctic-wav-arctic_b0148',
#  'cmu_us_bdl_arctic-wav-arctic_b0149',
#  'cmu_us_bdl_arctic-wav-arctic_b0150',
#  'cmu_us_bdl_arctic-wav-arctic_b0151',
#  'cmu_us_bdl_arctic-wav-arctic_b0152',
#  'cmu_us_bdl_arctic-wav-arctic_b0153',
#  'cmu_us_bdl_arctic-wav-arctic_b0154',
#  'cmu_us_bdl_arctic-wav-arctic_b0155',
#  'cmu_us_bdl_arctic-wav-arctic_b0156',
#  'cmu_us_bdl_arctic-wav-arctic_b0157',
#  'cmu_us_bdl_arctic-wav-arctic_b0158',
#  'cmu_us_bdl_arctic-wav-arctic_b0159',
#  'cmu_us_bdl_arctic-wav-arctic_b0160',
#  'cmu_us_bdl_arctic-wav-arctic_b0161',
#  'cmu_us_bdl_arctic-wav-arctic_b0162',
#  'cmu_us_bdl_arctic-wav-arctic_b0163',
#  'cmu_us_bdl_arctic-wav-arctic_b0164',
#  'cmu_us_bdl_arctic-wav-arctic_b0165',
#  'cmu_us_bdl_arctic-wav-arctic_b0166',
#  'cmu_us_bdl_arctic-wav-arctic_b0167',
#  'cmu_us_bdl_arctic-wav-arctic_b0168',
#  'cmu_us_bdl_arctic-wav-arctic_b0169',
#  'cmu_us_bdl_arctic-wav-arctic_b0170',
#  'cmu_us_bdl_arctic-wav-arctic_b0171',
#  'cmu_us_bdl_arctic-wav-arctic_b0172',
#  'cmu_us_bdl_arctic-wav-arctic_b0173',
#  'cmu_us_bdl_arctic-wav-arctic_b0174',
#  'cmu_us_bdl_arctic-wav-arctic_b0175',
#  'cmu_us_bdl_arctic-wav-arctic_b0176',
#  'cmu_us_bdl_arctic-wav-arctic_b0177',
#  'cmu_us_bdl_arctic-wav-arctic_b0178',
#  'cmu_us_bdl_arctic-wav-arctic_b0179',
#  'cmu_us_bdl_arctic-wav-arctic_b0180',
#  'cmu_us_bdl_arctic-wav-arctic_b0181',
#  'cmu_us_bdl_arctic-wav-arctic_b0182',
#  'cmu_us_bdl_arctic-wav-arctic_b0183',
#  'cmu_us_bdl_arctic-wav-arctic_b0184',
#  'cmu_us_bdl_arctic-wav-arctic_b0185',
#  'cmu_us_bdl_arctic-wav-arctic_b0186',
#  'cmu_us_bdl_arctic-wav-arctic_b0187',
#  'cmu_us_bdl_arctic-wav-arctic_b0188',
#  'cmu_us_bdl_arctic-wav-arctic_b0189',
#  'cmu_us_bdl_arctic-wav-arctic_b0190',
#  'cmu_us_bdl_arctic-wav-arctic_b0191',
#  'cmu_us_bdl_arctic-wav-arctic_b0192',
#  'cmu_us_bdl_arctic-wav-arctic_b0193',
#  'cmu_us_bdl_arctic-wav-arctic_b0194',
#  'cmu_us_bdl_arctic-wav-arctic_b0195',
#  'cmu_us_bdl_arctic-wav-arctic_b0196',
#  'cmu_us_bdl_arctic-wav-arctic_b0197',
#  'cmu_us_bdl_arctic-wav-arctic_b0198',
#  'cmu_us_bdl_arctic-wav-arctic_b0199',
#  'cmu_us_bdl_arctic-wav-arctic_b0200',
#  'cmu_us_bdl_arctic-wav-arctic_b0201',
#  'cmu_us_bdl_arctic-wav-arctic_b0202',
#  'cmu_us_bdl_arctic-wav-arctic_b0203',
#  'cmu_us_bdl_arctic-wav-arctic_b0204',
#  'cmu_us_bdl_arctic-wav-arctic_b0205',
#  'cmu_us_bdl_arctic-wav-arctic_b0206',
#  'cmu_us_bdl_arctic-wav-arctic_b0207',
#  'cmu_us_bdl_arctic-wav-arctic_b0208',
#  'cmu_us_bdl_arctic-wav-arctic_b0209',
#  'cmu_us_bdl_arctic-wav-arctic_b0210',
#  'cmu_us_bdl_arctic-wav-arctic_b0211',
#  'cmu_us_bdl_arctic-wav-arctic_b0212',
#  'cmu_us_bdl_arctic-wav-arctic_b0213',
#  'cmu_us_bdl_arctic-wav-arctic_b0214',
#  'cmu_us_bdl_arctic-wav-arctic_b0215',
#  'cmu_us_bdl_arctic-wav-arctic_b0216',
#  'cmu_us_bdl_arctic-wav-arctic_b0217',
#  'cmu_us_bdl_arctic-wav-arctic_b0218',
#  'cmu_us_bdl_arctic-wav-arctic_b0219',
#  'cmu_us_bdl_arctic-wav-arctic_b0220',
#  'cmu_us_bdl_arctic-wav-arctic_b0221',
#  'cmu_us_bdl_arctic-wav-arctic_b0222',
#  'cmu_us_bdl_arctic-wav-arctic_b0223',
#  'cmu_us_bdl_arctic-wav-arctic_b0224',
#  'cmu_us_bdl_arctic-wav-arctic_b0225',
#  'cmu_us_bdl_arctic-wav-arctic_b0226',
#  'cmu_us_bdl_arctic-wav-arctic_b0227',
#  'cmu_us_bdl_arctic-wav-arctic_b0228',
#  'cmu_us_bdl_arctic-wav-arctic_b0229',
#  'cmu_us_bdl_arctic-wav-arctic_b0230',
#  'cmu_us_bdl_arctic-wav-arctic_b0231',
#  'cmu_us_bdl_arctic-wav-arctic_b0232',
#  'cmu_us_bdl_arctic-wav-arctic_b0233',
#  'cmu_us_bdl_arctic-wav-arctic_b0234',
#  'cmu_us_bdl_arctic-wav-arctic_b0235',
#  'cmu_us_bdl_arctic-wav-arctic_b0236',
#  'cmu_us_bdl_arctic-wav-arctic_b0237',
#  'cmu_us_bdl_arctic-wav-arctic_b0238',
#  'cmu_us_bdl_arctic-wav-arctic_b0239',
#  'cmu_us_bdl_arctic-wav-arctic_b0240',
#  'cmu_us_bdl_arctic-wav-arctic_b0241',
#  'cmu_us_bdl_arctic-wav-arctic_b0242',
#  'cmu_us_bdl_arctic-wav-arctic_b0243',
#  'cmu_us_bdl_arctic-wav-arctic_b0244',
#  'cmu_us_bdl_arctic-wav-arctic_b0245',
#  'cmu_us_bdl_arctic-wav-arctic_b0246',
#  'cmu_us_bdl_arctic-wav-arctic_b0247',
#  'cmu_us_bdl_arctic-wav-arctic_b0248',
#  'cmu_us_bdl_arctic-wav-arctic_b0249',
#  'cmu_us_bdl_arctic-wav-arctic_b0250',
#  'cmu_us_bdl_arctic-wav-arctic_b0251',
#  'cmu_us_bdl_arctic-wav-arctic_b0252',
#  'cmu_us_bdl_arctic-wav-arctic_b0253',
#  'cmu_us_bdl_arctic-wav-arctic_b0254',
#  'cmu_us_bdl_arctic-wav-arctic_b0255',
#  'cmu_us_bdl_arctic-wav-arctic_b0256',
#  'cmu_us_bdl_arctic-wav-arctic_b0257',
#  'cmu_us_bdl_arctic-wav-arctic_b0258',
#  'cmu_us_bdl_arctic-wav-arctic_b0259',
#  'cmu_us_bdl_arctic-wav-arctic_b0260',
#  'cmu_us_bdl_arctic-wav-arctic_b0261',
#  'cmu_us_bdl_arctic-wav-arctic_b0262',
#  'cmu_us_bdl_arctic-wav-arctic_b0263',
#  'cmu_us_bdl_arctic-wav-arctic_b0264',
#  'cmu_us_bdl_arctic-wav-arctic_b0265',
#  'cmu_us_bdl_arctic-wav-arctic_b0266',
#  'cmu_us_bdl_arctic-wav-arctic_b0267',
#  'cmu_us_bdl_arctic-wav-arctic_b0268',
#  'cmu_us_bdl_arctic-wav-arctic_b0269']

# %%
indices = []
indices = [i for i, s in enumerate(embeddings_dataset['filename']) if "awb" in s]
print(f"awb indices min: {indices[0]}, max: {indices[-1]}")
# Out:
# awb indices min: 0, max: 1137

# %% [markdown]
# Ah, I was already using the Scottish voice, let's check the others

# %%
substrings = ['bdl', 'slt', 'jmk', 'awb', 'rms', 'clb', 'ksp']
for subs in substrings:  # not optimized but no matter
    indices = [i for i, s in enumerate(embeddings_dataset['filename']) if subs in s]
    print(f"{subs} indices min: {indices[0]}, max: {indices[-1]}")
# Out:
# bdl indices min: 1138, max: 2270
# slt indices min: 6799, max: 7930
# jmk indices min: 3403, max: 4534
# awb indices min: 0, max: 1137
# rms indices min: 5667, max: 6798
# clb indices min: 2271, max: 3402
# ksp indices min: 4535, max: 5666

# %%
for i in range(2271, 3402):
    message = f"How you doing {i}?"
    _speaker_embeddings = torch.tensor(embeddings_dataset[i]["xvector"]).unsqueeze(0).to(device)
    # 3407 is nice

    inputs = _tts_processor(text=message, return_tensors="pt").to(device)
    speech = _tts_model.generate_speech(inputs["input_ids"], _speaker_embeddings, vocoder=_tts_vocoder)
    play_audio(speech.to('cpu'), sampling_rate)

# %% [markdown]
# All voices are somewhat consistent. I will keep on using the US Female.
